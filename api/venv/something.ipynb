# %%
# %pip install beautifulsoup4
# %pip install requests

from bs4 import BeautifulSoup
import requests
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 1.8 MB/s eta 0:00:00
# ...
#   WARNING: The script normalizer is installed in '/Library/Frameworks/Python.framework/Versions/3.10/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://madgrades.com/explore'
response = requests.get(url)
html_content = response.content
print(html_content)
# Out:
# b'<!doctype html><html lang="en"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no"><meta name="theme-color" content="#000000"><link rel="manifest" href="/manifest.json"><link rel="shortcut icon" href="/favicon.ico"><title>Madgrades</title><meta name="description" content="Search and visualize University of Wisconsin Madison (UW Madison) course grade distributions." /><script async src="https://www.googletagmanager.com/gtag/js?id=G-B98Z7LLBL2"></script><script>function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[],gtag("js",new Date),gtag("config","G-B98Z7LLBL2")</script><script>!function(e,a,t,n,c,g,o){e.GoogleAnalyticsObject=c,e.ga=e.ga||function(){(e.ga.q=e.ga.q||[]).push(arguments)},e.ga.l=1*new Date,g=a.createElement(t),o=a.getElementsByTagName(t)[0],g.async=1,g.src="https://www.google-analytics.com/analytics.js",o.parentNode.insertBefore(g,o)}(window,document,"script",0,"ga"),ga("create","UA-1
# ...

# %%
soup = BeautifulSoup(html_content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# %pip install requests-html
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 3.9 MB/s eta 0:00:00
# ...
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   WARNING: The script tqdm is installed in '/Library/Frameworks/Python.framework/Versions/3.10/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Running setup.py install for bs4 ... done
# ...

# %%
from requests_html import HTMLSession
session = HTMLSession()

r = session.get('https://madgrades.com/explore')

r.html.render()  # this call executes the js in the page
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/niharsimhadri/MadHacks/react-flask-app/api/venv/something.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell:/Users/niharsimhadri/MadHacks/react-flask-app/api/venv/something.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> session = HTMLSession()
#       <a href='vscode-notebook-cell:/Users/niharsimhadri/MadHacks/react-flask-app/api/venv/something.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> r = session.get('https://madgrades.com/explore')
# ----> <a href='vscode-notebook-cell:/Users/niharsimhadri/MadHacks/react-flask-app/api/venv/something.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> r.html.render()  # this call executes the js in the page
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests_html.py:586, in HTML.render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
# ...

# %%
import requests

headers = {
    'Authorization': 'Token token=c7ccfbdc83ba40659bec454d73d76f3b',
}

response = requests.get('https://api.madgrades.com/v1/courses?page=50', headers=headers)
response.json()
# Out:
# {'currentPage': 50,
#  'totalPages': 431,
#  'totalCount': 10774,
#  'nextPageUrl': 'https://api.madgrades.com/v1/courses?page=51',
#  'results': [{'uuid': '71b88ffc-6231-3649-b831-73f51654edd5',
#    'number': 242,
#    'name': 'Literatures and Cultures of Eastern Europe',
#    'names': ['Lit & Culture-Eastrn Europe'],
#    'subjects': [{'name': 'SLAVIC (SLAVIC LANGUAGES)',
#      'abbreviation': 'SLAVIC',
#      'code': '888'}],
#    'url': 'https://api.madgrades.com/v1/courses/71b88ffc-6231-3649-b831-73f51654edd5'},
#   {'uuid': '229fe1e3-2e2f-3b39-bff1-63ab3d1a1411',
#    'number': 243,
#    'name': 'Practicum in World Languages (K-12)',
#    'names': ['Pract in World Lang (K-12)'],
#    'subjects': [{'name': 'CURRICULUM AND INSTRUCTION',
#      'abbreviation': 'CURRIC',
#      'code': '272'}],
#    'url': 'https://api.madgrades.com/v1/courses/229fe1e3-2e2f-3b39-bff1-63ab3d1a1411'},
#   {'uuid': '8265e306-7f3a-3b5d-8e52-5d6cb78587f6',
#    'number': 243,
# ...

# %%
import requests

headers = {
    'Authorization': 'Token token=c7ccfbdc83ba40659bec454d73d76f3b',
}

response = requests.get('https://api.madgrades.com/v1/courses?page=400', headers=headers)
response.json()
# Out:
# {'currentPage': 400,
#  'totalPages': 431,
#  'totalCount': 10774,
#  'nextPageUrl': 'https://api.madgrades.com/v1/courses?page=401',
#  'results': [{'uuid': '28f99338-5eaf-3fae-b101-18851232a981',
#    'number': 923,
#    'name': 'Seminar-Spectroscopy and Spectrochemical Analysis',
#    'names': ['Genomic Sciences Program Semin', 'Spctroscpy&Spectrochem Anal'],
#    'subjects': [{'name': 'CHEMISTRY', 'abbreviation': 'CHEM', 'code': '224'}],
#    'url': 'https://api.madgrades.com/v1/courses/28f99338-5eaf-3fae-b101-18851232a981'},
#   {'uuid': '76c64728-89b6-3308-9191-182272c19c3e',
#    'number': 923,
#    'name': 'Family Violence',
#    'names': ['Family Violence', None],
#    'subjects': [{'name': 'SOCIAL WORK',
#      'abbreviation': 'SOC WORK',
#      'code': '896'}],
#    'url': 'https://api.madgrades.com/v1/courses/76c64728-89b6-3308-9191-182272c19c3e'},
#   {'uuid': '54bd1f78-8b0e-34ba-a9d0-6adf9da6678f',
#    'number': 923,
#    'name': 'Seminar',
#    'names': ['Seminar'],
# ...

# %%
headers = {
    'Authorization': 'Token token=c7ccfbdc83ba40659bec454d73d76f3b',
}

response = requests.get('https://api.madgrades.com/v1/courses', headers=headers)
response.json()
# Out:
# 5

# %%
headers = {
    'Authorization': 'Token token=c7ccfbdc83ba40659bec454d73d76f3b',
}

response = requests.get('https://api.madgrades.com/v1/courses?page=1', headers=headers)
response.json()
# Out:
# {'currentPage': 1,
#  'totalPages': 431,
#  'totalCount': 10774,
#  'nextPageUrl': 'https://api.madgrades.com/v1/courses?page=2',
#  'results': [{'uuid': 'a3e3e1c3-543d-3bb5-ae65-5f2aec4ad1de',
#    'number': 1,
#    'name': 'Cooperative Education Program',
#    'names': ['Cooperative Education Prog'],
#    'subjects': [{'name': 'BIOMEDICAL ENGINEERING',
#      'abbreviation': 'B M E',
#      'code': '207'},
#     {'name': 'CHEMICAL AND BIOLOGICAL ENGINEERING',
#      'abbreviation': 'CBE',
#      'code': '220'},
#     {'name': 'CIVIL AND ENVIRONMENTAL ENGINEERING',
#      'abbreviation': 'CIV ENGR',
#      'code': '240'},
#     {'name': 'ELECTRICAL AND COMPUTER ENGINEERING',
#      'abbreviation': 'E C E',
#      'code': '320'},
#     {'name': 'ENGINEERING MECHANICS AND ASTRONAUTICS',
#      'abbreviation': 'E M A',
#      'code': '346'},
#     {'name': 'GEOLOGICAL ENGINEERING', 'abbreviation': 'G L E', 'code': '418'},
#     {'name': 'INDUSTRIAL AND SYSTEMS ENGINEERING',
# ...

# %%
headers = {
    'Authorization': 'Token token=c7ccfbdc83ba40659bec454d73d76f3b',
}

response = requests.get('https://api.madgrades.com/v1/courses?page=500', headers=headers)
response.json()['nextPageUrl']

if response.json()['nextPageUrl'] == None:
    print("hi")
# Out:
# hi

# %%
for res in response.json():
    print(res)
# Out:
# currentPage
# totalPages
# totalCount
# nextPageUrl
# results

# %%
for course in response.json()["results"]:
    print(course['name'])
# Out:
# Cooperative Education Program
# Cooperative Education/Co-op in Life Sciences Communication
# Cooperative Education Program
# Workshop in Dance Activity
# Cooperative Education/Co-op in Agricultural & Applied Economics
# Cooperative Education/Co-op in Forest & Wildlife Ecology
# Cooperative Education/Co-op in Animal Sciences
# Cooperative Education/Co-op in Soil Science
# Cooperative Educ-Microbiology
# Cooperative Educ in Diary Sci
# Ballroom Dance I
# Ballroom Dance II
# Modern Jazz Dance
# Fundamentals-Flute
# Contemporary Dance I
# Fundamentals: Double Reeds
# Contemporary Dance II
# Modern Dance III
# Fundamentals: Single Reeds
# Fundamentals-High Brass
# Introduction to Plant Science
# Ballet I
# Brass Fundamentals
# Agricultural Sales
# Ballet II

# %%
keepGetting = True
currPage = 1
allCourses = []

headers = {
    'Authorization': 'Token token=c7ccfbdc83ba40659bec454d73d76f3b',
    }

while keepGetting:
    response = requests.get(f'https://api.madgrades.com/v1/courses?page={currPage}', headers=headers)
    res_json = response.json()

    courses = res_json["results"]
    for course in courses:
        allCourses.append(course['name'])

    if res_json["nextPageUrl"] != None:
        currPage += 1
    else:
        keepGetting = False

# %%
len(allCourses)
# Out:
# 10774

# %%
course = 'deppler'

response = requests.get(f'https://api.madgrades.com/v1/instructors?query={course}', headers=headers)

# %%
response.json()
# Out:
# {'currentPage': 1,
#  'totalPages': 1,
#  'totalCount': 2,
#  'nextPageUrl': None,
#  'results': [{'id': 777651,
#    'name': 'DEBRA DEPPELER',
#    'url': 'https://api.madgrades.com/v1/instructors/777651'},
#   {'id': 470731,
#    'name': 'WALTER PEPPLER',
#    'url': 'https://api.madgrades.com/v1/instructors/470731'}]}

# %%
course = '100191'

response = requests.get(f'https://api.madgrades.com/v1/courses?instructor={course}', headers=headers)

# %%
print(response.json())
# Out:
# {'currentPage': 1, 'totalPages': 1, 'totalCount': 9, 'nextPageUrl': None, 'results': [{'uuid': 'a1bb30e8-5b04-3678-aaf8-8058a9a236f8', 'number': 100, 'name': 'Dept & Career Orientation', 'names': [None, 'Dept & Career Orientation'], 'subjects': [{'name': 'WILDLIFE ECOLOGY', 'abbreviation': 'WL ECOL', 'code': '960'}], 'url': 'https://api.madgrades.com/v1/courses/a1bb30e8-5b04-3678-aaf8-8058a9a236f8'}, {'uuid': 'da82e5fb-dc07-3f5b-94fa-697c3cd6d7ab', 'number': 101, 'name': 'Orientation to Wildlife Ecology', 'names': ['Orientation to Wildlfe Ecology', None], 'subjects': [{'name': 'FOREST ECOLOGY AND MANAGEMENT', 'abbreviation': 'F&W ECOL', 'code': '396'}], 'url': 'https://api.madgrades.com/v1/courses/da82e5fb-dc07-3f5b-94fa-697c3cd6d7ab'}, {'uuid': 'c5495cba-3c9a-3733-a258-0d92de24f093', 'number': 299, 'name': 'Independent Study', 'names': ['Independent Study'], 'subjects': [{'name': 'FOREST ECOLOGY AND MANAGEMENT', 'abbreviation': 'F&W ECOL', 'code': '396'}], 'url': 'https://api.madgra
# ...

# %%
url = 'https://api.madgrades.com/v1/terms'
response = requests.get(url)
html_content = response.content
print(html_content)
